# %% [markdown]
# # 作業
# * 選擇分類資料集(右下)-螺旋雙臂 - 交錯六群，限定特徵只能使用前兩個，隱藏層 2 層滿 (共 8 * 2 =16 個神經元)，
#   遞迴次數只允許跑到500次，但可以自由調整 批次大小、學習速率、啟動函數、正規化選項與參數
# * 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的上述幾項參數與 Test Loss 數
#
#   最低測試誤差：0.019
#
#   * Learning Rate: 0.1
#
#   * Activation: ReLU
#
#   * Regularization: L1
#
#   * Regularization Rate: 0.001
#
#   Learning Rate: 0.1
#   Activation: Tanh
#   Regularization: None
#   Test Loss: 0.179
#   ![](https://i.imgur.com/vyRt1xv.png)
#
#   Learning Rate: 0.3
#   Activation: Tanh
#   Regularization: None
#   Test Loss: 0.350
#   ![](https://i.imgur.com/aKLky1O.png)
#
#   Learning Rate: 0.03
#   Activation: ReLU
#   Regularization: None
#   Test Loss: 0.023
#   ![](https://i.imgur.com/8FcSF5Y.png)
#
#   Learning Rate: 0.1
#   Activation: ReLU
#   Regularization: None
#   Test Loss: 0.146
#   ![](https://i.imgur.com/oop4DKd.png)
#
#   Learning Rate: 0.3
#   Activation: ReLU
#   Regularization: None
#   Test Loss: 0.245
#   ![](https://i.imgur.com/hDmQxgP.png)
#
#   Learning Rate: 0.1
#   Activation: Tanh
#   Regularization: L2
#   Regularization Rate: 0.001
#   Test Loss: 0.049
#   ![](https://i.imgur.com/ZBXZHB3.png)
#
#   Learning Rate: 0.1
#   Activation: Tanh
#   Regularization: L2
#   Regularization Rate: 0.003
#   Test Loss: 0.153
#   ![](https://i.imgur.com/ycnRjsr.png)
#
#   Learning Rate: 0.03
#   Activation: ReLU
#   Regularization: L1
#   Regularization Rate: 0.001
#   Test Loss: 0.103
#   ![](https://i.imgur.com/8QlB8DK.png)
#
#   Learning Rate: 0.1
#   Activation: ReLU
#   Regularization: L1
#   Regularization Rate: 0.001
#   Test Loss: 0.019
#   ![](https://i.imgur.com/44MmyIU.png)
#
#   Learning Rate: 0.1
#   Activation: ReLU
#   Regularization: L2
#   Regularization Rate: 0.001
#   Test Loss: 0.029
#   ![](https://i.imgur.com/J8IZNrf.png)
#
#   Learning Rate: 0.3
#   Activation: ReLU
#   Regularization: L2
#   Regularization Rate: 0.001
#   Test Loss: 0.035
#   ![](https://i.imgur.com/QE4kKLm.png)
