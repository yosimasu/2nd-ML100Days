# %% [markdown]
# # 作業
# * 選擇迴歸資料集(右) - 交錯六群，在其他參數保持預設值的情況下，只允許調整隱藏層層數與神經元數量，且遵守下列限制
# > * 隱藏層神經元總數最多 8 個 (即 : 可以單層 8 個，或兩層 5 個與 3 個)
# > * 遞迴次數只允許跑到500次
# * 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的神經元參數與 Test Loss 數
#
#   以下為測試的結果：**最低的 Test Loss 是 0.013，兩層 Hidden Layer(6, 2)**
#
#   Test Loss: 0.014
#
#   Training Loss: 0.015
#
#   ![8](https://i.imgur.com/Ivwa121.png)
#
#   Test Loss: 0.014
#
#   Training Loss: 0.015
#
#   ![7x1](https://i.imgur.com/ST6mN01.png)
#
#   Test Loss: 0.013
#
#   Training Loss: 0.014
#
#   ![6x2](https://i.imgur.com/yo8kN8Z.png)
#
#   Test Loss: 0.016
#
#   Training Loss: 0.017
#
#   ![5x3](https://i.imgur.com/G9r3Dg3.png)
#
#   Test Loss: 0.015
#
#   Training Loss: 0.016
#
#   ![4x4](https://i.imgur.com/PyL5jUf.png)
#
#   Test Loss: 0.017
#
#   Training Loss: 0.018
#
#   ![3x5](https://i.imgur.com/209T7II.png)
#
#   Test Loss: 0.038
#
#   Training Loss: 0.037
#
#   ![2x6](https://i.imgur.com/frZyAHT.png)
#
#   Test Loss: 0.041
#
#   Training Loss: 0.044
#
#   ![1x7](https://i.imgur.com/KiNxaXb.png)
