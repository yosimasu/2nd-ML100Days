# %% [markdown]
# # 作業
# * 試著想想看, 非監督學習是否有可能使用評價函數 (Metric) 來鑑別好壞呢?
# (Hint : 可以分為 "有目標值" 與 "無目標值" 兩個方向思考)
#
#   * 有目標值，可以當作 supervised learning ，可以用 supervised learning 的 metric 來量測。
#   * 無目標值，沒有有效的 metric 。
