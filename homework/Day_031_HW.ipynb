# %% [markdown]
# ## 練習時間

# %% [markdown]
# 請觀看台大電機李宏毅教授的影片。李教授會用非常淺顯易懂的方式介紹甚麼是機器學習。

# %% [markdown]
# [youtube](https://www.youtube.com/watch?v=CXgbekl66jc)

# %% [markdown]
# ## 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?

# %%
自動駕駛，

目前機器學習在圖形辨識的領域已經非常成熟，而自動駕駛是圖形辨識的延伸應用，再加上強化學習是產生各種不同的駕駛情境，機器的駕駛技術就會越來越好。
